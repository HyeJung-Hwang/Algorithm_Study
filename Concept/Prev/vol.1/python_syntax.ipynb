# %%
# iterable:  iterable이 필요한 순간: 데이터를 하나씩 순서대로 처리할 때
# iterable = "next를 호출하면 다음 값을 줄 수 있는 객체"

# %%
# 정렬 
# 각 인접리스트를 우선순위 순으로 정렬
for node in graph:
    graph[node].sort(key = lambda x: priority[x])

# %%
# enumerate, iterable을 받아서, 하나씩 읽을 때 인덱스를 같이줌
